# %% [markdown]
# # Time-Series Visualization using plotly
# ### Arpita Jena

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime
import pandas_datareader.data as web
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
crime = pd.read_csv('Monthly_Property_Crime_2005_to_2015.csv')

# %%
crime.head()
# Out:
#                      Date       Category  IncidntNum
# 0  02/01/2014 12:00:00 AM       BURGLARY         506
# 1  02/01/2007 12:00:00 AM      VANDALISM         531
# 2  07/01/2012 12:00:00 AM       BURGLARY         522
# 3  07/01/2013 12:00:00 AM  LARCENY/THEFT        3318
# 4  08/01/2010 12:00:00 AM      VANDALISM         694

# %%
crime.dtypes
# Out:
# Date          object
# Category      object
# IncidntNum     int64
# dtype: object

# %%
crime['Date'] = crime['Date'].str[:10]
crime['Year'] = crime['Date'].str[6:10]
crime['month'] = crime['Date'].str[:2]

# %% [markdown]
# ### Line Chart

# %%
data = crime.groupby('Year').sum()
data = data.add_suffix('_Count').reset_index()

# %%
data = [
    go.Scatter(
        x=data['Year'], 
        y=data['IncidntNum_Count']
    )
]
fig = go.Figure(data = data)
iplot(fig, filename='basic-line')
# Out:
# <div id="5aabcec6-383b-4d9e-8736-24cf9a8c3ada" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5aabcec6-383b-4d9e-8736-24cf9a8c3ada", [{"y": [58368, 50150, 46023, 45647, 44633, 42581, 43885, 52379, 57241, 59679, 64887], "x": ["2005", "2006", "2007", "2008", "2009", "2010", "2011", "2012", "2013", "2014", "2015"], "type": "scatter"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# The above plot shows an overall trend of total crimes across the years. Number of crimes decreased till 2010 after which it is constantly incrrasing.

# %% [markdown]
# ### Multi Line Chart

# %%
monthly_crime = crime.groupby(['Year', 'Date']).sum()
monthly_crime = monthly_crime.add_suffix('_Count').reset_index()

# %%
monthly_crime['month'] = monthly_crime['Date'].str[:2]

# %%
trace0 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2015']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2015']['IncidntNum_Count'],
    mode = 'lines',
    name = '2015'
)
                                           
trace1 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2014']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2014']['IncidntNum_Count'],
    mode = 'lines',
    name = '2014'
)

trace2 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2013']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2013']['IncidntNum_Count'],
    mode = 'lines',
    name = '2013'
)
                                           
trace3 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2012']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2012']['IncidntNum_Count'],
    mode = 'lines',
    name = '2012'
)
                                           
trace4 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2011']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2011']['IncidntNum_Count'],
    mode = 'lines',
    name = '2011'
)

trace5 = go.Scatter(
    x = monthly_crime.loc[monthly_crime['Year'] == '2010']['month'],
    y = monthly_crime.loc[monthly_crime['Year'] == '2010']['IncidntNum_Count'],
    mode = 'lines',
    name = '2010'
)

# %%
data = [trace0, trace1, trace2, trace3, trace4, trace5]
fig = go.Figure(data = data)
iplot(fig, filename='line-mode')
# Out:
# <div id="b497dd23-6869-48e4-858b-b5bb424b7ff5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b497dd23-6869-48e4-858b-b5bb424b7ff5", [{"y": [5555, 4945, 5750, 5394, 6009, 5741, 5885, 5651, 5294, 5222, 4692, 4749], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2015", "mode": "lines"}, {"y": [4771, 4164, 4826, 4886, 4650, 4477, 5065, 5518, 4921, 5652, 5242, 5507], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2014", "mode": "lines"}, {"y": [4668, 4215, 4613, 4607, 4355, 4380, 5074, 5300, 5638, 5190, 4629, 4572], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2013", "mode": "lines"}, {"y": [3809, 3741, 3768, 4073, 4254, 4197, 4459, 4732, 4808, 5202, 4789, 4547], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2012", "mode": "lines"}, {"y": [3655, 3222, 3856, 3534, 3676, 3434, 3415, 3644, 3608, 3934, 3798, 4109], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2011", "mode": "lines"}, {"y": [3688, 3078, 3355, 3311, 3495, 3577, 3659, 3855, 3721, 3654, 3668, 3520], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "2010", "mode": "lines"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# The above plot shows a monthwise distribution of crimes from 2010 to 2015. There is no pattern indicating a particular month when crime is more.

# %%
sorted_data = crime.sort_values(['Year', 'month'])
trace0 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='VEHICLE THEFT']['Date'],
    y = sorted_data[sorted_data['Category']=='VEHICLE THEFT']['IncidntNum'],
    mode = 'lines',
    name = 'VEHICLE THEFT'
)
                                           
trace1 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='ARSON']['Date'],
    y = sorted_data[sorted_data['Category']=='ARSON']['IncidntNum'],
    mode = 'lines',
    name = 'ARSON'
)

trace2 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='BURGLARY']['Date'],
    y = sorted_data[sorted_data['Category']=='BURGLARY']['IncidntNum'],
    mode = 'lines',
    name = 'BURGLARY'
)
                                           
trace3 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='LARCENY/THEFT']['Date'],
    y = sorted_data[sorted_data['Category']=='LARCENY/THEFT']['IncidntNum'],
    mode = 'lines',
    name = 'LARCENY/THEFT'
)
                                           
trace4 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='STOLEN PROPERTY']['Date'],
    y = sorted_data[sorted_data['Category']=='STOLEN PROPERTY']['IncidntNum'],
    mode = 'lines',
    name = 'STOLEN PROPERTY'
)

trace5 = go.Scatter(
    x = sorted_data[sorted_data['Category']=='VANDALISM']['Date'],
    y = sorted_data[sorted_data['Category']=='VANDALISM']['IncidntNum'],
    mode = 'lines',
    name = 'VANDALISM'
)

data = [trace0, trace1, trace2, trace3, trace4, trace5]
fig = go.Figure(data = data)
iplot(fig, filename='line-mode')
# Out:
# <div id="7d569a7f-c599-4a15-92c6-492c37c5fd49" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("7d569a7f-c599-4a15-92c6-492c37c5fd49", [{"y": [1685, 1366, 1476, 1594, 1590, 1394, 1429, 1412, 1430, 1774, 1723, 1321, 609, 572, 565, 572, 547, 651, 673, 687, 570, 628, 604, 613, 523, 466, 511, 408, 376, 488, 633, 707, 692, 619, 544, 493, 519, 475, 527, 538, 510, 427, 460, 510, 579, 576, 444, 488, 545, 403, 459, 395, 402, 393, 438, 489, 433, 416, 436, 374, 366, 363, 352, 326, 271, 366, 388, 381, 403, 359, 398, 373, 339, 312, 465, 359, 375, 350, 274, 370, 454, 513, 451, 500, 428, 474, 451, 473, 455, 497, 600, 573, 548, 551, 580, 553, 523, 470, 455, 440, 503, 515, 495, 584, 699, 567, 453, 537, 517, 442, 528, 650, 641, 683, 650, 645, 496, 704, 566, 586, 606, 552, 626, 728, 825, 717, 633, 630, 628, 710, 639, 649], "x": ["01/01/2005", "02/01/2005", "03/01/2005", "04/01/2005", "05/01/2005", "06/01/2005", "07/01/2005", "08/01/2005", "09/01/2005", "10/01/2005", "11/01/2005", "12/01/2005", "01/01/2006", "02/01/2006", "03/01/2006", "04/01/2006", "05/01/2006", "06/01/2006", "07/01/2006", "08/01/2006", "09/01/2006", "10/01/2006", "11/01/2006", "12/01/2006", "01/01/2007", "02/01/2007", "03/01/2007", "04/01/2007", "05/01/2007", "06/01/2007", "07/01/2007", "08/01/2007", "09/01/2007", "10/01/2007", "11/01/2007", "12/01/2007", "01/01/2008", "02/01/2008", "03/01/2008", "04/01/2008", "05/01/2008", "06/01/2008", "07/01/2008", "08/01/2008", "09/01/2008", "10/01/2008", "11/01/2008", "12/01/2008", "01/01/2009", "02/01/2009", "03/01/2009", "04/01/2009", "05/01/2009", "06/01/2009", "07/01/2009", "08/01/2009", "09/01/2009", "10/01/2009", "11/01/2009", "12/01/2009", "01/01/2010", "02/01/2010", "03/01/2010", "04/01/2010", "05/01/2010", "06/01/2010", "07/01/2010", "08/01/2010", "09/01/2010", "10/01/2010", "11/01/2010", "12/01/2010", "01/01/2011", "02/01/2011", "03/01/2011", "04/01/2011", "05/01/2011", "06/01/2011", "07/01/2011", "08/01/2011", "09/01/2011", "10/01/2011", "11/01/2011", "12/01/2011", "01/01/2012", "02/01/2012", "03/01/2012", "04/01/2012", "05/01/2012", "06/01/2012", "07/01/2012", "08/01/2012", "09/01/2012", "10/01/2012", "11/01/2012", "12/01/2012", "01/01/2013", "02/01/2013", "03/01/2013", "04/01/2013", "05/01/2013", "06/01/2013", "07/01/2013", "08/01/2013", "09/01/2013", "10/01/2013", "11/01/2013", "12/01/2013", "01/01/2014", "02/01/2014", "03/01/2014", "04/01/2014", "05/01/2014", "06/01/2014", "07/01/2014", "08/01/2014", "09/01/2014", "10/01/2014", "11/01/2014", "12/01/2014", "01/01/2015", "02/01/2015", "03/01/2015", "04/01/2015", "05/01/2015", "06/01/2015", "07/01/2015", "08/01/2015", "09/01/2015", "10/01/2015", "11/01/2015", "12/01/2015"], "type": "scatter", "name": "VEHICLE THEFT", "mode": "lines"}, {"y": [21, 17, 19, 24, 13, 23, 23, 20, 17, 18, 19, 17, 24, 13, 16, 19, 27, 14, 24, 24, 27, 27, 11, 14, 23, 12, 17, 20, 29, 21, 29, 16, 27, 18, 23, 11, 16, 12, 34, 20, 18, 20, 21, 24, 28, 18, 20, 17, 20, 17, 16, 18, 17, 15, 30, 19, 18, 14, 25, 13, 19, 9, 19, 16, 21, 22, 18, 22, 19, 21, 17, 6, 25, 19, 11, 23, 14, 13, 20, 17, 18, 14, 17, 12, 29, 16, 12, 18, 17, 21, 25, 17, 25, 18, 18, 21, 37, 23, 22, 11, 19, 20, 25, 17, 19, 21, 24, 10, 32, 22, 13, 18, 15, 25, 20, 20, 14, 24, 28, 22, 41, 31, 21, 30, 30, 31, 23, 16, 16, 28, 25, 19], "x": ["01/01/2005", "02/01/2005", "03/01/2005", "04/01/2005", "05/01/2005", "06/01/2005", "07/01/2005", "08/01/2005", "09/01/2005", "10/01/2005", "11/01/2005", "12/01/2005", "01/01/2006", "02/01/2006", "03/01/2006", "04/01/2006", "05/01/2006", "06/01/2006", "07/01/2006", "08/01/2006", "09/01/2006", "10/01/2006", "11/01/2006", "12/01/2006", "01/01/2007", "02/01/2007", "03/01/2007", "04/01/2007", "05/01/2007", "06/01/2007", "07/01/2007", "08/01/2007", "09/01/2007", "10/01/2007", "11/01/2007", "12/01/2007", "01/01/2008", "02/01/2008", "03/01/ ...

# %% [markdown]
# There is a sharp drop in vehicle thefts after April 2006 which might be due to strict surveillance. But from 2011 it is experiencing slightly increasing trend. Larceny/theft seem to be increasing with time. All other categories seem to be some what stationary.
# ### Heatmap

# %%
cat_crime = crime.groupby(['Year', 'Category']).sum()
cat_crime = cat_crime.add_suffix('_Count').reset_index()

# %%
trace = go.Heatmap(z=cat_crime['IncidntNum_Count'],
                   x=cat_crime['Year'],
                   y=cat_crime['Category'])
data=[trace]

layout = go.Layout(
    title='Category wise yearly crime',
    xaxis = dict(ticks='', nticks=11),
    yaxis = dict(ticks='' )
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='labelled-heatmap')
# Out:
# <div id="cac2932d-ff98-466e-b8bb-5740e43b3e44" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cac2932d-ff98-466e-b8bb-5740e43b3e44", [{"y": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT", "ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "x": ["2005", "2005", "2005", "2005", "2005", "2005", "2006", "2006", "2006", "2006", "2006", "2006", "2007", "2007", "2007", "2007", "2007", "2007", "2008", "2008", "2008", "2008", "2008", "2008", "2009", "2009", "2009", "2009", "2009", "2009", "2010", "2010", "2010", "2010", "2010", "2010", "2011", "2011", "2011", "2011", "2011", "2011", "2012", "2012", "2012", "2012", "2012", "2012", "2013", "2013", "2013", "2013", "2013", "2013", "2014", "2014", "2014", "2014", "2014", "2014", "2015", "2015", "2015", "2015", "2015", "2015"], "z": [231, 7071, 25319, 540, 7013, 18194, 240, 7004, 27352, 575, 7688, 7291, 246, 5454, 25770, 527, 7566, 6460, 248, 5679, 25807, 518, 7342, 6053, 222, 5379, 25585, 660, 7604, 5183, 209, 4966, 24446, 680, 7934, 4346, 203, 4987, 25905, 785, 7243, 4762, 237, 6243, 30976, 932, 7808, 6183, 248, 6195, 36412, 1224, 6921, 6241, 253, 6066, 38003, 1084, 7165, 7108, 311, 5931, 42068, 959, 7675, 7943], "type": "heatmap"}], {"title": "Category wise yearly crime", "xaxis": {"nticks": 11, "ticks": ""}, "yaxis": {"ticks": ""}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# 2005 saw highest number of vehicle thefts. Larceny/Theft cases are gradually increasing every year. Arson and vandalism cases are almost constant across years.
# ### Stacked Bar Chart

# %%
trace1 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2015']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2015']['IncidntNum_Count'],
    name='2015'
)
trace2 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2014']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2014']['IncidntNum_Count'],
    name='2014'
)

trace3 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2013']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2013']['IncidntNum_Count'],
    name='2013'
)
trace4 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2012']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2012']['IncidntNum_Count'],
    name='2012'
)

trace5 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2011']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2011']['IncidntNum_Count'],
    name='2011'
)
trace6 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2010']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2010']['IncidntNum_Count'],
    name='2010'
)

data = [trace1, trace2, trace3, trace4, trace5, trace6]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='stacked-bar')
# Out:
# <div id="de2ad6ba-8515-4327-a4d9-a5086f600817" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("de2ad6ba-8515-4327-a4d9-a5086f600817", [{"y": [311, 5931, 42068, 959, 7675, 7943], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2015"}, {"y": [253, 6066, 38003, 1084, 7165, 7108], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2014"}, {"y": [248, 6195, 36412, 1224, 6921, 6241], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2013"}, {"y": [237, 6243, 30976, 932, 7808, 6183], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2012"}, {"y": [203, 4987, 25905, 785, 7243, 4762], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2011"}, {"y": [209, 4966, 24446, 680, 7934, 4346], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2010"}], {"barmode": "stack"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# The above plot is a stacked version of total crime committed in each category in each year from 2010 to 2015. Crime in larceny/theft dominates over all other types of crimes.
# ### Bar Chart

# %%
trace1 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2009']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2009']['IncidntNum_Count'],
    name='2009'
)
trace2 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2008']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2008']['IncidntNum_Count'],
    name='2008'
)

trace3 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2007']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2007']['IncidntNum_Count'],
    name='2007'
)
trace4 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2006']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2006']['IncidntNum_Count'],
    name='2006'
)

trace5 = go.Bar(
    x=cat_crime.loc[cat_crime['Year'] == '2005']['Category'],
    y=cat_crime.loc[cat_crime['Year'] == '2005']['IncidntNum_Count'],
    name='2005'
)


data = [trace1, trace2, trace3, trace4, trace5]


fig = go.Figure(data=data)
iplot(fig, filename='bar')
# Out:
# <div id="455bf9fd-392c-4f99-8347-0bc3ce957ff6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("455bf9fd-392c-4f99-8347-0bc3ce957ff6", [{"y": [222, 5379, 25585, 660, 7604, 5183], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2009"}, {"y": [248, 5679, 25807, 518, 7342, 6053], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2008"}, {"y": [246, 5454, 25770, 527, 7566, 6460], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2007"}, {"y": [240, 7004, 27352, 575, 7688, 7291], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2006"}, {"y": [231, 7071, 25319, 540, 7013, 18194], "x": ["ARSON", "BURGLARY", "LARCENY/THEFT", "STOLEN PROPERTY", "VANDALISM", "VEHICLE THEFT"], "type": "bar", "name": "2005"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# The above plot is a stacked version of total crime committed in each category in each year from 2005 to 2009. Number of vehicle theft in 2005 was unusually high than other years.
# ### Stacked Area Chart

# %%
crime[(crime['Category']=='VANDALISM') & (crime['Year'] == '2015')].month
# Out:
# 35     11
# 118    09
# 161    12
# 211    08
# 240    05
# 300    07
# 343    10
# 352    06
# 372    04
# 420    03
# 485    01
# 637    02
# Name: month, dtype: object

# %%
crime_sorted = crime[crime['Year'] == '2015'].sort_values('Date')

# %%
trace1 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='ARSON')].month,
    y=crime_sorted[(crime_sorted['Category']=='ARSON')].IncidntNum,
    fill='tozeroy',
    name = 'ARSON', # Style name/legend entry with html tags
    
)
trace2 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='BURGLARY')].month,
    y=crime_sorted[(crime_sorted['Category']=='BURGLARY')].IncidntNum,
    fill='tonexty',
    name = 'BURGLARY'
)
trace3 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='LARCENY/THEFT')].month,
    y=crime_sorted[(crime_sorted['Category']=='LARCENY/THEFT')].IncidntNum,
    fill='tonexty',
    name = 'LARCENY/THEFT'
    
)
trace4 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='STOLEN PROPERTY')].month,
    y=crime_sorted[(crime_sorted['Category']=='STOLEN PROPERTY')].IncidntNum,
    fill='tonexty',
    name = 'STOLEN PROPERTY'
)
trace5 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='VANDALISM')].month,
    y=crime_sorted[(crime_sorted['Category']=='VANDALISM')].IncidntNum,
    fill='tonexty',
    name = 'VANDALISM'
)
trace6 = go.Scatter(
    x=crime_sorted[(crime_sorted['Category']=='VEHICLE THEFT')].month,
    y=crime_sorted[(crime_sorted['Category']=='VEHICLE THEFT')].IncidntNum,
    fill='tonexty',
    name = 'VEHICLE THEFT'
)


data = [trace1, trace2,trace3, trace4, trace5, trace6]

fig = go.Figure(data=data)
iplot(fig)
# Out:
# <div id="00766848-e064-48be-b635-c6a3860ca2f6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("00766848-e064-48be-b635-c6a3860ca2f6", [{"y": [41, 31, 21, 30, 30, 31, 23, 16, 16, 28, 25, 19], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "ARSON", "fill": "tozeroy"}, {"y": [495, 481, 513, 490, 568, 498, 490, 490, 467, 458, 457, 524], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "BURGLARY", "fill": "tonexty"}, {"y": [3715, 3284, 3820, 3482, 3846, 3758, 3879, 3702, 3430, 3268, 2945, 2939], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "LARCENY/THEFT", "fill": "tonexty"}, {"y": [82, 84, 92, 77, 68, 75, 87, 84, 90, 84, 65, 71], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "STOLEN PROPERTY", "fill": "tonexty"}, {"y": [616, 513, 678, 587, 672, 662, 773, 729, 663, 674, 561, 547], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "VANDALISM", "fill": "tonexty"}, {"y": [606, 552, 626, 728, 825, 717, 633, 630, 628, 710, 639, 649], "x": ["01", "02", "03", "04", "05", "06", "07", "08", "09", "10", "11", "12"], "type": "scatter", "name": "VEHICLE THEFT", "fill": "tonexty"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %% [markdown]
# Above is a stacked area chart showing crime across different category across each month of 2015. Both Larceny/theft and vehicle theft reduced towards the second half of the year.
# ### Animated Scatter Plot

# %%
months = sorted(crime['month'].unique())
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
cats = []
for cat in crime['Category']:
    if cat not in cats:
        cats.append(cat)
figure = {
    'data': [],
    'layout': {},
    'frames': []
}

figure['layout']['xaxis'] = {'range': [2005,2015], 'title': 'Year'}
figure['layout']['yaxis'] = {'title': 'Number of crime cases', 'range': [0, 1000]}
figure['layout']['hovermode'] = 'closest'
figure['layout']['sliders'] = {
    'args': [
        'transition', {
            'duration': 400,
            'easing': 'cubic-in-out'
        }
    ],
    'initialValue': '01',
    'plotlycommand': 'animate',
    'values': months,
    'visible': True
}
figure['layout']['updatemenus'] = [
    {
        'buttons': [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw': False},
                         'fromcurrent': True, 'transition': {'duration': 300, 'easing': 'quadratic-in-out'}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False}, 'mode': 'immediate',
                'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Month:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300, 'easing': 'cubic-in-out'},
    'pad': {'b': 10, 't': 50},
    'len': 0.9,
    'x': 0.1,
    'y': 0,
    'steps': []
}

# make data
Month = '01'
for cat in cats:
    crime_by_month = crime[crime['month'] == Month]
    crime_by_month_and_cont = crime_by_month[crime_by_month['Category'] == cat]

    data_dict = {
        'x': list(crime_by_month_and_cont['Year']),
        'y': list(crime_by_month_and_cont['IncidntNum']),
        'mode': 'markers',
        'text': list(crime_by_month_and_cont['Category']),
        'name': cat
    }
    figure['data'].append(data_dict)
    
# make frames
for month in months:
    frame = {'data': [], 'name': str(month)}
    for cat in cats:
        crime_by_month = crime[crime['month'] == month]
        crime_by_month_and_cont = crime_by_month[crime_by_month['Category'] == cat]

        data_dict = {
            'x': list(crime_by_month_and_cont['Year']),
            'y': list(crime_by_month_and_cont['IncidntNum']),
            'mode': 'markers',
            'text': list(crime_by_month_and_cont['Category']),
            'name': cat
        }
        frame['data'].append(data_dict)

    figure['frames'].append(frame)
    slider_step = {'args': [
        [month],
        {'frame': {'duration': 300, 'redraw': False},
         'mode': 'immediate',
       'transition': {'duration': 300}}
     ],
     'label': month,
     'method': 'animate'}
    sliders_dict['steps'].append(slider_step)

    
figure['layout']['sliders'] = [sliders_dict]
iplot(figure)
# Out:
# <div id="a3a5a14b-0a00-40ea-b679-8eec5800a966" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'a3a5a14b-0a00-40ea-b679-8eec5800a966',
#             [{"y": [421, 527, 618, 507, 495, 442, 441, 698, 471, 501, 434], "x": ["2010", "2006", "2014", "2013", "2015", "2011", "2009", "2005", "2012", "2007", "2008"], "text": ["BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY"], "mode": "markers", "name": "BURGLARY"}, {"y": [493, 605, 648, 642, 577, 566, 663, 616, 702, 601, 556], "x": ["2005", "2012", "2007", "2008", "2014", "2013", "2011", "2015", "2010", "2006", "2009"], "text": ["VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM"], "mode": "markers", "name": "VANDALISM"}, {"y": [1932, 2116, 2351, 2109, 3715, 2941, 2932, 2162, 1979, 2201, 2038], "x": ["2009", "2010", "2006", "2011", "2015", "2014", "2013", "2008", "2007", "2012", "2005"], "text": ["LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT"], "mode": "markers", "name": "LARCENY/THEFT"}, {"y": [545, 366, 609, 523, 517, 339, 606, 523, 519, 1685, 428], "x": ["2009", "2010", "2006", "2013", "2014", "2011", "2015", "2007", "2008", "2005", "2012"], "text": ["VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT"], "mode": "markers", "name": "VEHICLE THEFT"}, {"y": [82, 77, 86, 103, 55, 64, 46, 75, 56, 32, 46], "x": ["2015", "2011", "2014", "2013", "2006", "2010", "2009", "2012", "2005", "2008", "2007"], "text": ["STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY"], "mode": "markers", "name": "STOLEN PROPERTY"}, {"y": [23, 16, 21, 29, 20, 24, 19, 37, 32, 25, 41], "x": ["2007", "2008", "2005", "2012", "2009", "2006", "2010", "2013", "2014", "2011", "2015"], "text": ["ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON"], "mode": "markers", "name": "ARSON"}],
#             {"sliders": [{"yanchor": "top", "currentvalue": {"visible": true, "prefix": "Month:", "font": {"size": 20}, "xanchor": "right"}, "transition": {"duration": 300, "easing": "cubic-in-out"}, "xanchor": "left", "pad": {"b": 10, "t": 50}, "len": 0.9, "active": 0, "steps": [{"args": [["01"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "01"}, {"args": [["02"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "02"}, {"args": [["03"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "03"}, {"args": [["04"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "04"}, {"args": [["05"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "05"}, {"args": [["06"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "06"}, {"args": [["07"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "07"}, {"args": [["08"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "08"}, {"args": [["09"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "09"}, {"args": [["10"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "10"}, {"args": [["11"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "11"}, {"args": [["12"], {"frame": {"duration": 300, "redraw": false}, "transition": {"duration": 300}, "mode": "immediate"}], "method": "animate", "label": "12"}], "y": 0, "x": 0.1}], "hovermode": "closest", "xaxis": {"range": [2005, 2015], "title": "Year"}, "updatemenus": [{"yanchor": "top", "direction": "left", "showactive": false, "xanchor": "right", "buttons": [{"args": [null, {"frame": {"duration": 500, "redraw": false}, "transition": {"duration": 300, "easing": "quadratic-in-out"}, "fromcurrent": true}], "method": "animate", "label": "Play"}, {"args": [[null], {"frame": {"duration": 0, "redraw": false}, "transition": {"duration": 0}, "mode": "immediate"}], "method": "animate", "label": "Pause"}], "pad": {"r": 10, "t": 87}, "y": 0, "x": 0.1, "type": "buttons"}], "yaxis": {"range": [0, 1000], "title": "Number of crime cases"}},
#             {"linkText": "Export to plot.ly", "showLink": true}
#         ).then(function () {return Plotly.addFrames('a3a5a14b-0a00-40ea-b679-8eec5800a966',[{"data": [{"y": [421, 527, 618, 507, 495, 442, 441, 698, 471, 501, 434], "x": ["2010", "2006", "2014", "2013", "2015", "2011", "2009", "2005", "2012", "2007", "2008"], "text": ["BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY", "BURGLARY"], "mode": "markers", "name": "BURGLARY"}, {"y": [493, 605, 648, 642, 577, 566, 663, 616, 702, 601, 556], "x": ["2005", "2012", "2007", "2008", "2014", "2013", "2011", "2015", "2010", "2006", "2009"], "text": ["VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM", "VANDALISM"], "mode": "markers", "name": "VANDALISM"}, {"y": [1932, 2116, 2351, 2109, 3715, 2941, 2932, 2162, 1979, 2201, 2038], "x": ["2009", "2010", "2006", "2011", "2015", "2014", "2013", "2008", "2007", "2012", "2005"], "text": ["LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT", "LARCENY/THEFT"], "mode": "markers", "name": "LARCENY/THEFT"}, {"y": [545, 366, 609, 523, 517, 339, 606, 523, 519, 1685, 428], "x": ["2009", "2010", "2006", "2013", "2014", "2011", "2015", "2007", "2008", "2005", "2012"], "text": ["VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT", "VEHICLE THEFT"], "mode": "markers", "name": "VEHICLE THEFT"}, {"y": [82, 77, 86, 103, 55, 64, 46, 75, 56, 32, 46], "x": ["2015", "2011", "2014", "2013", "2006", "2010", "2009", "2012", "2005", "2008", "2007"], "text": ["STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY", "STOLEN PROPERTY"], "mode": "markers", "name": "STOLEN PROPERTY"}, {"y": [23, 16, 21, 29, 20, 24, 19, 37, 32, 25, 41], "x": ["2007", "2008", "2005", "2012", "2009", "2006", "2010", "2013", "2014", "2011", "2015"], "text": ["ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON", "ARSON"], "mode": "markers", "name": "ARSON"}], "name": "01"}, {"data": [{"y": [506, 440, 464, 389, 481, 315, 547, 382, 382, 515, 374], "x": ["2014", "2013", "2012", "2009", "2015", "2011", "2005", "2008", "2007", "2006", "2010"], "text": ["BURGLARY", "BURG

# %% [markdown]
# Here is an animated scatter plot showing crimes in each category across each year and month.
